# %%
from IPython.display import Video

Video("test5.mp4")
# Out:
# <video src="test5.mp4" controls  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
from IPython.display import Image
print("Kod za test broj 5")
Image("5.png")
# Out:
# Kod za test broj 5

# %%
import pandas as pd
print("Rezultati")
df = pd.read_csv("rezultati.csv")
print(df)
# Out:
# Rezultati
#   roboti  test1  test2  test3  test4
# 0   mate     11     12     13     14
# 1   tika     11     12     13     14
